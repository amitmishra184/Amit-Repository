# %% [markdown]
# ** Random **
# - randint
# - random
# - choice
# - sample
# - seed

# %%
import random 
random.randint(1,100)
# Out:
# 45

# %%
random.random()
# Out:
# 0.5656045422363088

# %%
l = [1,2,3,4,5]
random.choice(l)
# Out:
# 5

# %%
l = ['red','red','yellow','red']
random.sample(l,4)
# Out:
# ['red', 'red', 'red', 'yellow']

# %%
random.seed(1)
random.random()
#random.random()
# Out:
# 0.13436424411240122

# %%
random.seed("hello")
print(random.randint(1, 10))
# Out:
# 6

# %%
random.seed(1)
l = ['red','red','yellow','red']
print(random.sample(l,4))
random.seed()
print(random.sample(l,4))
# Out:
# ['red', 'yellow', 'red', 'red']
# ['red', 'red', 'yellow', 'red']

# %% [markdown]
# **math**

# %%
import math
math.sqrt(9)
# Out:
# 3.0

# %%
math.pow(2,3)
# Out:
# 8.0

# %%
math.ceil
(round(math.pi,3))
# Out:
# 3.142

# %%
math.e**2
# Out:
# 7.3890560989306495

# %% [markdown]
# **time**

# %%
import time
a= time.time()
time.sleep(10)
b= time.time()
b-a
# Out:
# 10.002547025680542

# %% [markdown]
# **keyword**

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %% [markdown]
# **os**

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Ayaan\\Documents\\Naresh IT\\Python'

# %%
os.makedirs('amit1')

# %% [markdown]
# **date**

# %%
# from datetime import date
# date.today()

import datetime
datetime.date
today = date.today()
print(today)
# Out:
# 2025-11-22
